# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Data

# %%
path = r'/Users/nataliawijaya/Documents/Bootcamp/Instacart Basket Analysis/02 Data'

# %%
path
# Out:
# '/Users/nataliawijaya/Documents/Bootcamp/Instacart Basket Analysis/02 Data'

# %%
# Importing 'orders_products_merged_updated.pkl'
df_ords_prods_merged = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge       price_range_loc  \
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 18)

# %%
# Create a subset up to 1 million rows (:1000000)
df = df_ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge       price_range_loc  \
# ...

# %% [markdown]
# ## Grouping Data with Pandas

# %% [markdown]
# To recap, you should always use the groupby() function as part of a series of steps, namely, the following:
# 1. Split the data into groups based on some criteria.
# 2. Apply a function to each group separately.
# 3. Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.

# %%
df.groupby('product_name')

# %% [markdown]
# ## Aggregating Data with agg()

# %% [markdown]
# Aggregation functions create summaries of selected columns and store these summary values in new columns. These summaries usually take the form of a descriptive statistic, for instance, a mean, median, maximum, or minimum (the very concept that you encountered in pivot tables in Excel). Aggregate columns have more uses beyond the immediate analysis.

# %% [markdown]
# ### Performing a Single Aggregation

# %% [markdown]
# If you were to calculate the mean of the “order_number” column grouped by the “department_id” column, you could quickly compare the average number of orders per user across each Instacart department. This will involve two of the steps:
# 1. Split the data into groups based on “department_id.”
# 2. Apply the agg() function to each group to obtain the mean values for the “order_number” column.

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge       price_range_loc  \
# ...

# %%
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# There are some aggregations that can be conducted without use of the agg() function. For instance, the command above could be replaced with a command that uses the mean() function to achieve the same results:

# %%
# SQUARE BRACKETS (In general, stick to brackets when it comes to indexing!)
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# Rather than including the column name within square brackets, as in the example above, you could also set the column name off with a dot, for instance:

# %%
# DOT NOTATION 
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# ### Performing Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ### Aggregating Data with transform()

# %% [markdown]
# - Creating a loyalty flag column in your ords_prods_merge dataframe.
# - You’ll do this by first using the transform() function, which will create a new column containing the maximum frequency of the “order_number” column, and then using the loc() function, which will create a second column containing a flag designating whether a customer is “loyal” or not.
#
# Step:
# 1. Split the data into groups based on the “user_id” column.
# 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation.
#
# Once this process is complete, you can use the “max_order” column to create another new column that assigns a loyalty flag to each customer according to the criteria (via the loc() function).

# %%
# In this case, all three steps can be included in a single line of code
df_ords_prods_merged['max_order'] = df_ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/kj/ff_yw10j6_zbkk839hkzgftr0000gn/T/ipykernel_9441/4171536106.py:2: FutureWarning: The provided callable <function amax at 0x110f23ce0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merged['max_order'] = df_ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merged.head(25)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# ### Deriving Columns with loc()

# %% [markdown]
# - If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# - If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# - If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <=10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['max_order'] > 10) & (df_ords_prods_merged['max_order'] <= 40), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge       price_range_loc  \
# ...

# %%
df_ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# #### This brings to the end of the three-step process:
# 1. Started by grouping your data,
# 2. Followed up by applying an aggregation function,
# 3. Finished everything off by using the resulting aggregation to create a flag column.

# %% [markdown]
# ## Exercise

# %% [markdown]
# #### In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge       price_range_loc  \
# ...

# %%
df_ords_prods_merged.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #### Analyze the result. How do the results for the entire dataframe differ from those of the subset?

# %%
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# The average result of order_number from the subset (1000000) is greater than the average result of entire dataframe (except the department_id: 17)

# %% [markdown]
# #### The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge       price_range_loc  \
# ...

# %%
df_ords_prods_merged.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ##### Observation:
#
# 1. It is interesting to see that new customers have a higher average purchase price than the other 2 customer categories and even loyal customers have a lower average purchase than the others
# 2. The maximum price here seems odd compared to the mean value itself. The value of 99.999 has skewed the distribution so further analysis for this value will be performed

# %%
df_ords_prods_merged['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
df_ords_prods_merged['prices'].sort_values(ascending = False)
# Out:
# 29165979    99999.0
# 29165985    99999.0
# 29165519    99999.0
# 29165518    99999.0
# 29165517    99999.0
#              ...
# 7870751         1.0
# 7870750         1.0
# 7870749         1.0
# 7870748         1.0
# 30034999        1.0
# Name: prices, Length: 32404859, dtype: float64

# %%
df_ords_prods_merged['prices'].drop_duplicates().sort_values(ascending = False)
# Out:
# 29165516    99999.0
# 10030345    14900.0
# 18504754       25.0
# 25758883       24.9
# 28425432       24.8
#              ...
# 3384024         1.4
# 632766          1.3
# 5488887         1.2
# 5147325         1.1
# 60725           1.0
# Name: prices, Length: 242, dtype: float64

# %% [markdown]
# Observation: The 99.999 and 14.900 prices look weird (that's a lot higher than the others)

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'].isin([99999.0,14900.0])]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 10030345    912404       17            12                   2
# 10030346    603376       17            22                   6
# 10030347   3264360      135             2                   2
# 10030348    892534      135             3                   0
# 10030349    229704      342             8                   1
# ...            ...      ...           ...                 ...
# 29166209   2249946   204099            29                   0
# 29166210   2363282   204099            31                   0
# 29166211   3181945   204395            13                   3
# 29166212   2486215   205227             7                   3
# 29166213   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 10030345                 14                     5.0       21553
# 10030346                 16                     4.0       21553
# ...

# %%
df_high_prices = df_ords_prods_merged.loc[df_ords_prods_merged['prices'].isin([99999.0,14900.0])]

# %%
df_high_prices['prices'].value_counts(dropna = False)
# Out:
# prices
# 14900.0    4429
# 99999.0     698
# Name: count, dtype: int64

# %%
df_high_prices.describe()
# Out:
#            order_id        user_id  order_number  orders_day_of_week  \
# count  5.127000e+03    5127.000000   5127.000000         5127.000000
# mean   1.708876e+06  106117.185684     15.302126            2.750536
# std    9.838956e+05   58594.982659     16.691849            2.010892
# min    4.300000e+01      17.000000      1.000000            0.000000
# 25%    8.642320e+05   58136.000000      4.000000            1.000000
# 50%    1.693799e+06  106021.000000      9.000000            3.000000
# 75%    2.567244e+06  156389.000000     20.000000            5.000000
# max    3.421047e+06  206049.000000     99.000000            6.000000
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count        5127.000000             4776.000000   5127.000000
# mean           13.473376               11.899079  23201.815682
# std             4.137326                9.068019   4153.742747
# min             0.000000                0.000000  21553.000000
# ...

# %% [markdown]
# ##### Observation:
# 1. Incredibly high prices (14.900 and 99.999) both from the department_id 16 with product_id 21553 and 33664
# 2. Next step: Find the product_name with product_id 21553 and 33664

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['product_id'].isin([21553, 33664])]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 10030345    912404       17            12                   2
# 10030346    603376       17            22                   6
# 10030347   3264360      135             2                   2
# 10030348    892534      135             3                   0
# 10030349    229704      342             8                   1
# ...            ...      ...           ...                 ...
# 29166209   2249946   204099            29                   0
# 29166210   2363282   204099            31                   0
# 29166211   3181945   204395            13                   3
# 29166212   2486215   205227             7                   3
# 29166213   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 10030345                 14                     5.0       21553
# 10030346                 16                     4.0       21553
# ...

# %% [markdown]
# ##### Observation about finding:
# 1. The price of 14.900 comes from Lowfat 2% Milkfat Cottage Cheese (with product_id 21553)
# 2. The price of 99.999 comes from 2 % Reduced Fat Milk (with product_id 33664)

# %%
# Confirm the finding number 1
# The price of 14.900 comes from Lowfat 2% Milkfat Cottage Cheese (with product_id 21553)
df_ords_prods_merged.loc[df_ords_prods_merged['prices'].isin([14900.0])]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 10030345    912404       17            12                   2
# 10030346    603376       17            22                   6
# 10030347   3264360      135             2                   2
# 10030348    892534      135             3                   0
# 10030349    229704      342             8                   1
# ...            ...      ...           ...                 ...
# 10034769   3172853   205650            18                   1
# 10034770   2504315   205818             3                   5
# 10034771   1108388   205818             5                   4
# 10034772   1916142   206049             1                   2
# 10034773    379732   206049             4                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 10030345                 14                     5.0       21553
# 10030346                 16                     4.0       21553
# ...

# %% [markdown]
# ##### Observation:
# 4429 values found with the price $14.900

# %%
df_high_price_14900 = df_ords_prods_merged.loc[df_ords_prods_merged['prices'].isin([14900.0])]

# %%
df_high_price_14900['product_name'].value_counts(dropna = False)
# Out:
# product_name
# Lowfat 2% Milkfat Cottage Cheese    4429
# Name: count, dtype: int64

# %% [markdown]
# ##### Observation:
# The Lowfat 2% Milkfat Cottage Cheese product has value_counts = 4429 which has the exact same number as the product which has a price of 14.900, meaning that the entire price of 14.900 belongs to the entire  Lowfat 2% Milkfat Cottage Cheese product

# %%
# Confirm the finding number 2
# The price of 99.999 comes from 2 % Reduced Fat Milk (with product_id 33664)
df_ords_prods_merged.loc[df_ords_prods_merged['prices'].isin([99999.0])]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 29165516    183964      873             3                   0
# 29165517   1851256      873             4                   6
# 29165518   1915696     1893             1                   5
# 29165519   2763293     1893             2                   4
# 29165520   2564805     1893             4                   1
# ...            ...      ...           ...                 ...
# 29166209   2249946   204099            29                   0
# 29166210   2363282   204099            31                   0
# 29166211   3181945   204395            13                   3
# 29166212   2486215   205227             7                   3
# 29166213   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 29165516                 10                     7.0       33664
# 29165517                 12                    13.0       33664
# ...

# %% [markdown]
# ##### Observation:
# 698 values found with the price $99.999

# %%
df_high_price_99999 = df_ords_prods_merged.loc[df_ords_prods_merged['prices'].isin([99999.0])]

# %%
df_high_price_99999['product_name'].value_counts(dropna = False)
# Out:
# product_name
# 2 % Reduced Fat  Milk    698
# Name: count, dtype: int64

# %% [markdown]
# ##### Observation:
# The 2 % Reduced Fat  Milk product has value_counts = 698 which has the exact same number as the product which has a price of 99.999, meaning that the entire price of 99.999 belongs to the entire 2 % Reduced Fat  Milk product

# %% [markdown]
# ##### Next Step:
# 1. Create a new dataframe with department_id = 16 (df_dept_16)
# 2. Then another dataframe that excludes the high prices (df_dept_16_normal) --> using ~ to exclude the data

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['department_id'] == 16]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 35791      2539329        1             1                   2
# 35792      3241517      140            14                   4
# 35793      1204424      293             1                   0
# 35794      2748748      293             2                   1
# 35795      1216787      293             5                   4
# ...            ...      ...           ...                 ...
# 32404819   1517645   191198            67                   6
# 32404820   1104816   198258            14                   1
# 32404822   1812848   191508             5                   3
# 32404823    638659   196973            11                   2
# 32404836   3004721   197459             2                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 35791                     8                     NaN       14084
# 35792                    16                     7.0       14084
# ...

# %%
# Create a new dataframe with department_id = 16 (df_dept_16)
df_dept_16 = df_ords_prods_merged.loc[df_ords_prods_merged['department_id'] == 16]

# %%
df_dept_16.head()
# Out:
#        order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 35791   2539329        1             1                   2                  8
# 35792   3241517      140            14                   4                 16
# 35793   1204424      293             1                   0                 20
# 35794   2748748      293             2                   1                 20
# 35795   1216787      293             5                   4                 18
#
#        days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 35791                     NaN       14084                  2          0
# 35792                     7.0       14084                 25          0
# 35793                     NaN       14084                  2          0
# 35794                    15.0       14084                  2          1
# 35795                    17.0       14084                 10          1
#
# ...

# %%
df_dept_16['product_name'].value_counts(dropna = False)
# Out:
# product_name
# Organic Whole Milk                                           137905
# Organic Half & Half                                           76360
# Half & Half                                                   69217
# Organic Whole String Cheese                                   59676
# Organic Unsweetened Almond Milk                               57895
#                                                               ...
# Pumpkin Spice Almond Nog                                          1
# Greek Blended Cherry Fat Free Yogurt                              1
# Kefir Raspberry                                                   1
# Cinnamon Rice Pudding Snacks                                      1
# Lowfat Cherry Lime Supernova Kefir Cultured Milk Smoothie         1
# Name: count, Length: 3444, dtype: int64

# %%
# Then another dataframe that excludes the high prices (df_dept_16_normal) --> using ~ to exclude the data
df_dept_16_normal = df_dept_16.loc[~df_dept_16['prices'].isin([99999, 14900])]

# %%
df_dept_16_normal.head()
# Out:
#        order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 35791   2539329        1             1                   2                  8
# 35792   3241517      140            14                   4                 16
# 35793   1204424      293             1                   0                 20
# 35794   2748748      293             2                   1                 20
# 35795   1216787      293             5                   4                 18
#
#        days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 35791                     NaN       14084                  2          0
# 35792                     7.0       14084                 25          0
# 35793                     NaN       14084                  2          0
# 35794                    15.0       14084                  2          1
# 35795                    17.0       14084                 10          1
#
# ...

# %%
df_dept_16_normal['prices'].describe()
# Out:
# count    5.393620e+06
# mean     8.335056e+00
# std      4.098207e+00
# min      1.000000e+00
# 25%      4.800000e+00
# 50%      8.800000e+00
# 75%      1.190000e+01
# max      1.500000e+01
# Name: prices, dtype: float64

# %%
df_dept_16_normal['prices'].max()
# Out:
# 15.0

# %% [markdown]
# ##### Observation:
# After excluding unusual values, the max price becomes more reasonable

# %% [markdown]
# ##### Fixing the problem:
# 1. Finding the most closest value to replace 14.900 (Lowfat 2% Milkfat Cottage Cheese, product_id = 21553)
# 2. Finding the most closest value to replace 99.999 (2 % Reduced Fat Milk, product_id = 33664)

# %%
# First: Observation on Lowfat 2% Milkfat Cottage Cheese (with product_id 21553)
# Create a filter for products that contain 'Lowfat', '2%', 'Milkfat', and Cottage Cheese' in the name, in df_dept_16_normal
cottage_cheese = df_dept_16_normal.query('product_name.str.contains("Lowfat") & product_name.str.contains("2%") & product_name.str.contains("Cottage Cheese") & product_name.str.contains("Milkfat")')

# %%
cottage_cheese['product_name'].value_counts(dropna = False)
# Out:
# product_name
# Small Curd Lowfat 2% Milkfat Cottage Cheese                                2397
# Cottage Doubles Peach, 2% Milkfat Lowfat Cottage Cheese & Peach Topping     350
# Grade A Pasteurized 2% Milkfat Lowfat Cottage Cheese with Pineapple          32
# Cottage Cheese 2% Milkfat Lowfat,Blueberry Topping                           14
# Name: count, dtype: int64

# %%
cottage_cheese['prices'].describe()
# Out:
# count    2793.000000
# mean        7.005979
# std         1.829113
# min         2.400000
# 25%         7.700000
# 50%         7.700000
# 75%         7.700000
# max        11.800000
# Name: prices, dtype: float64

# %% [markdown]
# ##### Observation:
# Now the mean, min and max prices for cottage_cheese are 7.0, 2.4, 11.8. Since this result makes more sense, the price of product ID 21553, named 'Lowfat 2% Milkfat Cottage Cheese' will be replaced from 14.900 and inputed by the mean value mentioned above (7.005979)

# %%
# Second: Observation on 2 % Reduced Fat Milk (with product_id 33664)
# Create a filter for products that contain '2%', Reduced Fat', and 'Milk' in the name, in df_dept_16_normal
reduced_fat_milk = df_dept_16_normal.query('product_name.str.contains("2%") & product_name.str.contains("Reduced Fat") & product_name.str.contains("Milk")')

# %%
reduced_fat_milk['product_name'].value_counts(dropna = False)
# Out:
# product_name
# Organic Reduced Fat 2% Milk                                              47839
# 2% Reduced Fat Milk                                                      37091
# Organic 2% Reduced Fat Milk                                              23244
# Reduced Fat 2% Milk                                                      17320
# 2% Reduced Fat Organic Milk                                              16356
# Organic Milk Reduced Fat, 2% Milkfat                                     12737
# Dha Omega 3 Reduced Fat 2% Milk                                          10148
# Milk, Reduced Fat, 2% Milkfat                                             7558
# Lactose Free 2% Reduced Fat Milk                                          7114
# Grassmilk 2% Reduced Fat Milk                                             5049
# Reduced Fat 2% Chocolate Milk                                             3243
# Reduced Fat 2% Lactose-Free Milk                                          3050
# ...

# %%
reduced_fat_milk['prices'].describe()
# Out:
# count    202238.000000
# mean          9.086900
# std           3.064869
# min           1.200000
# 25%           7.900000
# 50%           9.200000
# 75%          11.400000
# max          14.700000
# Name: prices, dtype: float64

# %% [markdown]
# ##### Observation:
# Now the mean, min and max prices for reduced_fat_milk are 9.08, 1.2, 14.7. Since this result makes more sense, the price of product ID 33664, named '2 % Reduced Fat Milk' will be reduced from 99.999 to 9.99 (which is close to their average value)

# %% [markdown]
# ##### Fixing the problem:
# Replace the price '99999' with '9.99' and impute the value '14900' with the mean price from cottage_cheese

# %%
df_ords_prods_merged['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
df_ords_prods_merged['prices'] = df_ords_prods_merged['prices'].replace({99999: 9.99, 14900: cottage_cheese['prices'].mean()})

# %%
df_ords_prods_merged['prices'].describe()
# Out:
# count    3.240486e+07
# mean     7.790934e+00
# std      4.241496e+00
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      2.500000e+01
# Name: prices, dtype: float64

# %% [markdown]
# ##### Observation:
# Now the mean, std, min and max results make more sense than the previous output

# %% [markdown]
# #### Determine the difference between the spending habits of the three types of customers you identified. Determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
df_ords_prods_merged.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.773499  1.0  25.0
# New customer      7.801156  1.0  25.0
# Regular customer  7.798207  1.0  25.0

# %% [markdown]
# ##### Observation:
# 1. Now the mean value becomes lower and max value is more reasonable (instead of 99999, now 25)
# 2. The order of results is still the same: new customer holds the highest purchase price followed by regular customer then loyal customer, but the difference now is small compared to the previous result

# %% [markdown]
# #### The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge       price_range_loc  \
# ...

# %% [markdown]
# ##### Using transform() function
# - Creating a spending_flag column in df_ords_prods_merged dataframe.
# - First create a new column containing the average of the “prices” column by using transform() function, and then using the loc() function which will create a second column containing a flag designating whether a customer is high spender or low spender.

# %%
df_ords_prods_merged['average_price'] = df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/kj/ff_yw10j6_zbkk839hkzgftr0000gn/T/ipykernel_9441/1229806165.py:1: FutureWarning: The provided callable <function mean at 0x110f2ca40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_ords_prods_merged['average_price'] = df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  department_id  prices  _merge       price_range_loc  \
# ...

# %%
# Rounding the average 
df_ords_prods_merged['average_price'] = df_ords_prods_merged['average_price'].round(2)

# %%
df_ords_prods_merged['average_price']
# Out:
# 0           6.37
# 1           6.37
# 2           6.37
# 3           6.37
# 4           6.37
#             ...
# 32404854    6.91
# 32404855    6.91
# 32404856    7.63
# 32404857    7.63
# 32404858    7.68
# Name: average_price, Length: 32404859, dtype: float64

# %%
# Creating a 'spending_flag' flag
df_ords_prods_merged.loc[df_ords_prods_merged['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Creating a 'spending_flag' flag
df_ords_prods_merged.loc[df_ords_prods_merged['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices  _merge       price_range_loc     busiest_day  \
# ...

# %%
# Checking the frequency
df_ords_prods_merged['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     32284501
# High spender      120358
# Name: count, dtype: int64

# %% [markdown]
# #### In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Using transform() function
df_ords_prods_merged['median_days_prior_orders'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/kj/ff_yw10j6_zbkk839hkzgftr0000gn/T/ipykernel_9441/3944351444.py:2: FutureWarning: The provided callable <function median at 0x112c6eb60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df_ords_prods_merged['median_days_prior_orders'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge       price_range_loc     busiest_day  \
# ...

# %%
# Creating a 'order_frequency_flag' flag
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_prior_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Creating a 'order_frequency_flag' flag
df_ords_prods_merged.loc[(df_ords_prods_merged['median_days_prior_orders'] > 10) & (df_ords_prods_merged['median_days_prior_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Creating a 'order_frequency_flag' flag
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_prior_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...       price_range_loc     busiest_day     busiest_days  \
# ...

# %%
# Checking the frequency
df_ords_prods_merged['order_frequency_flag'].value_counts()
# Out:
# order_frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# nan                             5
# Name: count, dtype: int64

# %%
# Checking the nan values
df_ords_prods_merged[df_ords_prods_merged['order_frequency_flag'].isnull()]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, _merge, price_range_loc, busiest_day, busiest_days, busiest_period_of_day, max_order, loyalty_flag, average_price, spending_flag, median_days_prior_orders, order_frequency_flag]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Checking the nan values
df_ords_prods_merged[df_ords_prods_merged['median_days_prior_orders'].isnull()]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 13645692    895835   159838             1                   0
# 17251990    895835   159838             1                   0
# 17622767    895835   159838             1                   0
# 24138593    895835   159838             1                   0
# 25880002    895835   159838             1                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 13645692                 17                     NaN       10749
# 17251990                 17                     NaN       33401
# 17622767                 17                     NaN       23695
# 24138593                 17                     NaN       21334
# 25880002                 17                     NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# ...

# %%
# Checking the nan values
df_ords_prods_merged[df_ords_prods_merged['median_days_prior_orders'].isnull()][['user_id', 'days_since_prior_order', 'median_days_prior_orders', 'order_frequency_flag']]
# Out:
#           user_id  days_since_prior_order  median_days_prior_orders  \
# 13645692   159838                     NaN                       NaN
# 17251990   159838                     NaN                       NaN
# 17622767   159838                     NaN                       NaN
# 24138593   159838                     NaN                       NaN
# 25880002   159838                     NaN                       NaN
#
#          order_frequency_flag
# 13645692                  nan
# 17251990                  nan
# 17622767                  nan
# 24138593                  nan
# 25880002                  nan

# %%
# Check user_id 159838
df_ords_prods_merged[df_ords_prods_merged['user_id'] == 159838]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 13645692    895835   159838             1                   0
# 17251990    895835   159838             1                   0
# 17622767    895835   159838             1                   0
# 24138593    895835   159838             1                   0
# 25880002    895835   159838             1                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 13645692                 17                     NaN       10749
# 17251990                 17                     NaN       33401
# 17622767                 17                     NaN       23695
# 24138593                 17                     NaN       21334
# 25880002                 17                     NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# ...

# %% [markdown]
# ##### Observation
# user_id 159838 seems to be a new customer. Therefore, I leave the value of NaN as it is

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...       price_range_loc     busiest_day     busiest_days  \
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 24)

# %% [markdown]
# #### Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder

# %%
# Exporting df_ords_prods_merged dataframe as “orders_products_merged_updated_2.pkl” in “Prepared Data” folder
df_ords_prods_merged.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged_updated_2.pkl'))
